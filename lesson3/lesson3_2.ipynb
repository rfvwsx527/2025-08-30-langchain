# %% [markdown]
# curl http://localhost:11434/api/generate -d "{
# \"model\": \"gemma3:1b\",
# \"prompt\": \"Why is the sky blue?\"
# }"

# %%
import requests
import json

# 方法1：使用 requests.post() 發送 POST 請求到 Ollama API
url = "http://localhost:11434/api/generate"

# 準備請求資料
data = {
    "model": "llama3.2",
    "prompt": "Why is the sky blue?"
}

# 發送 POST 請求
response = requests.post(url, json=data)

# 檢查回應狀態
print("狀態碼:", response.status_code)

# 顯示回應內容
if response.status_code == 200:
    print("回應內容:")
    print(response.text)
else:
    print("請求失敗:", response.text)
# Out:
# 狀態碼: 200
# 回應內容:
# {"model":"llama3.2","created_at":"2025-09-13T06:01:13.700839Z","response":"The","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:13.7448572Z","response":" sky","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:13.7877184Z","response":" appears","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:13.8313141Z","response":" blue","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:13.8759353Z","response":" because","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:13.9185081Z","response":" of","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:13.957861Z","response":" a","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:13.9963201Z","response":" phenomenon","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.0375881Z","response":" called","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.0778254Z","response":" Ray","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.118058Z","response":"leigh","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.1593904Z","response":" scattering","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.1985117Z","response":",","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.2386446Z","response":" named","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.2777415Z","response":" after","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.3181849Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.3572919Z","response":" British","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.3966398Z","response":" physicist","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.435308Z","response":" Lord","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.4755121Z","response":" Ray","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.5138652Z","response":"leigh","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.555904Z","response":".","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.5957181Z","response":" When","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.6374316Z","response":" sunlight","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.6775022Z","response":" enters","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.7167924Z","response":" Earth","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.7576006Z","response":"'s","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.7981283Z","response":" atmosphere","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.8389431Z","response":",","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.8782483Z","response":" it","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.9167994Z","response":" encounters","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.9582311Z","response":" tiny","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:14.9960328Z","response":" molecules","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.0357325Z","response":" of","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.0756455Z","response":" gases","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.1150511Z","response":" such","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.1564401Z","response":" as","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.195833Z","response":" nitrogen","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.2351645Z","response":" and","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.275228Z","response":" oxygen","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.3155137Z","response":".\n\n","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.3571147Z","response":"These","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.3967983Z","response":" molecules","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.4352151Z","response":" scatter","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.4754467Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.5149596Z","response":" light","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.555591Z","response":" in","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.5952316Z","response":" all","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.6367587Z","response":" directions","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.6758321Z","response":",","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.7155494Z","response":" but","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.7562935Z","response":" they","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.7960125Z","response":" scatter","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.8354232Z","response":" shorter","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.8757046Z","response":" (","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.914677Z","response":"blue","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.9551103Z","response":")","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:15.9971763Z","response":" wavelengths","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:16.0407632Z","response":" more","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:16.0918669Z","response":" than","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:16.136262Z","response":" longer","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:16.1747495Z","response":" (","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:16.2148438Z","response":"red","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:16.2563558Z","response":")","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:16.2956606Z","response":" wavelengths","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:16.3343645Z","response":".","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:16.3758747Z","response":" This","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:16.4150061Z","response":" is","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:16.4565747Z","response":" because","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:16.4951089Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:16.5347309Z","response":" smaller","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:16.5756968Z","response":" molecules","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:16.6150856Z","response":" are","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:16.6573304Z","response":" more","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:16.6975686Z","response":" effective","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:16.7393957Z","response":" at","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:16.778636Z","response":" scattering","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:16.8197435Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:16.8598251Z","response":" shorter","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:16.8972757Z","response":" wavelengths","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:16.9394482Z","response":".\n\n","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:16.9782644Z","response":"As","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.0172034Z","response":" a","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.0577595Z","response":" result","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.0973228Z","response":",","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.1362961Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.1777205Z","response":" blue","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.2172336Z","response":" light","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.2579834Z","response":" is","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.2971741Z","response":" dispersed","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.3380638Z","response":" throughout","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.3777151Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.4168428Z","response":" atmosphere","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.4569051Z","response":",","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.4962856Z","response":" reaching","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.5372882Z","response":" our","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.576339Z","response":" eyes","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.6164713Z","response":" from","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.658432Z","response":" all","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.6984714Z","response":" parts","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.7409534Z","response":" of","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.7806611Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.8224422Z","response":" sky","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.8630548Z","response":".","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.9057009Z","response":" This","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.9462285Z","response":" is","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:17.9885885Z","response":" why","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:18.0285454Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:18.0689354Z","response":" sky","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:18.1101467Z","response":" typically","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:18.1494763Z","response":" appears","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:18.1902731Z","response":" blue","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:18.2304029Z","response":" during","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:18.2745253Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:18.3164302Z","response":" daytime","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:18.3603851Z","response":",","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:18.4004099Z","response":" especially","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:18.4432357Z","response":" in","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:18.4834117Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:18.5242865Z","response":" direction","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:18.563647Z","response":" of","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:18.6058455Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:18.6452752Z","response":" sun","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:18.68517Z","response":".\n\n","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:18.7254157Z","response":"Here","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:18.765252Z","response":"'s","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:18.8074641Z","response":" a","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:18.8462859Z","response":" simplified","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:18.8883978Z","response":" explanation","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:18.9277041Z","response":":\n\n","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:18.9676682Z","response":"1","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.0072536Z","response":".","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.0489466Z","response":" Sun","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.0902232Z","response":"light","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.1305554Z","response":" enters","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.1703594Z","response":" Earth","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.2098374Z","response":"'s","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.2498315Z","response":" atmosphere","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.2910362Z","response":".\n","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.3318168Z","response":"2","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.3722611Z","response":".","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.412746Z","response":" The","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.4526079Z","response":" tiny","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.4925127Z","response":" molecules","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.5333181Z","response":" in","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.5743928Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.6148399Z","response":" air","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.6575392Z","response":" scatter","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.6985106Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.7399992Z","response":" shorter","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.7798589Z","response":" (","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.8212986Z","response":"blue","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.861695Z","response":")","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.9006454Z","response":" wavelengths","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.9412363Z","response":" more","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:19.9807791Z","response":" than","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:20.0191077Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:20.0600767Z","response":" longer","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:20.1006238Z","response":" (","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:20.1452002Z","response":"red","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:20.1883008Z","response":")","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:20.2298464Z","response":" wavelengths","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:20.2722883Z","response":".\n","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:20.3155318Z","response":"3","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:20.3582169Z","response":".","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:20.3981477Z","response":" The","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:20.4405877Z","response":" scattered","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:20.4806837Z","response":" blue","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:20.524419Z","response":" light","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:20.5656364Z","response":" reaches","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:20.6074543Z","response":" our","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:20.6487559Z","response":" eyes","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:20.6900671Z","response":" from","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:20.7301434Z","response":" all","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:20.7725703Z","response":" parts","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:20.8124407Z","response":" of","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:20.8525614Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:20.8937547Z","response":" sky","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:20.9345036Z","response":".\n","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:20.975721Z","response":"4","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.0135747Z","response":".","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.0547328Z","response":" Our","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.0944117Z","response":" eyes","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.1349154Z","response":" perceive","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.1751954Z","response":" this","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.2141418Z","response":" scattered","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.2561457Z","response":" blue","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.2940966Z","response":" light","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.3348461Z","response":" as","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.3763808Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.4147396Z","response":" color","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.4561213Z","response":" blue","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.4941513Z","response":".\n\n","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.5360459Z","response":"It","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.5759943Z","response":"'s","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.6153815Z","response":" worth","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.6558707Z","response":" noting","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.69444Z","response":" that","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.7357024Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.7763139Z","response":" color","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.8147073Z","response":" of","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.8549446Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.8942688Z","response":" sky","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.9341483Z","response":" can","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:21.9764778Z","response":" vary","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.0163926Z","response":" depending","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.0577683Z","response":" on","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.0963159Z","response":" several","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.1364531Z","response":" factors","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.1781061Z","response":",","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.218609Z","response":" such","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.2604714Z","response":" as","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.2983647Z","response":":\n\n","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.3400964Z","response":"*","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.379728Z","response":" Time","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.4175719Z","response":" of","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.4582681Z","response":" day","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.4971707Z","response":":","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.5367522Z","response":" During","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.5785471Z","response":" sunrise","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.6180683Z","response":" and","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.6582644Z","response":" sunset","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.6968027Z","response":",","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.7378306Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.7768708Z","response":" sky","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.8167206Z","response":" can","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.858269Z","response":" take","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.8961573Z","response":" on","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.9365137Z","response":" hues","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:22.977748Z","response":" of","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.015546Z","response":" red","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.0550114Z","response":",","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.0946291Z","response":" orange","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.1354988Z","response":",","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.1758471Z","response":" and","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.2135732Z","response":" pink","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.2530247Z","response":" due","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.2923581Z","response":" to","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.332293Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.3715527Z","response":" scattering","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.4120678Z","response":" of","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.4536331Z","response":" longer","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.4912827Z","response":" wavelengths","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.5301084Z","response":".\n","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.5722021Z","response":"*","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.6134292Z","response":" Atmospheric","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.6556669Z","response":" conditions","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.6947753Z","response":":","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.7349915Z","response":" Dust","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.7748744Z","response":",","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.8124987Z","response":" pollution","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.8523574Z","response":",","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.8911877Z","response":" and","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.9307192Z","response":" water","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:23.9722465Z","response":" vapor","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.010582Z","response":" in","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.0507695Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.091091Z","response":" air","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.13132Z","response":" can","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.1737263Z","response":" scatter","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.2113748Z","response":" light","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.2516042Z","response":" and","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.2917556Z","response":" change","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.3315957Z","response":" its","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.3727832Z","response":" appearance","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.4109435Z","response":".\n","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.452507Z","response":"*","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.4929192Z","response":" Alt","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.5335138Z","response":"itude","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.575125Z","response":" and","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.6137013Z","response":" atmospheric","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.6553729Z","response":" pressure","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.6928153Z","response":":","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.7331871Z","response":" The","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.7751407Z","response":" color","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.8167607Z","response":" of","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.8602446Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.899052Z","response":" sky","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.9426027Z","response":" can","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:24.9833387Z","response":" also","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:25.0224993Z","response":" be","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:25.0618354Z","response":" affected","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:25.1030656Z","response":" by","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:25.1424945Z","response":" changes","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:25.1827322Z","response":" in","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:25.222275Z","response":" altitude","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:25.2620131Z","response":" and","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:25.3005009Z","response":" atmospheric","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:25.3423635Z","response":" pressure","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:25.3832747Z","response":".\n\n","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:25.4246135Z","response":"However","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:25.4649269Z","response":",","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:25.5060363Z","response":" under","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:25.5460457Z","response":" clear","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:25.5873223Z","response":" conditions","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:25.629183Z","response":" during","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:25.6708917Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:25.710196Z","response":" daytime","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:25.7514757Z","response":",","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:25.7920225Z","response":" Ray","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:25.8331992Z","response":"leigh","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:25.876592Z","response":" scattering","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:25.9200964Z","response":" is","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:25.960349Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:26.0001233Z","response":" primary","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:26.0428612Z","response":" reason","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:26.0830591Z","response":" why","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:26.1252405Z","response":" the","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:26.1642236Z","response":" sky","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:26.2055459Z","response":" appears","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:26.2463231Z","response":" blue","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:26.2875761Z","response":".","done":false}
# {"model":"llama3.2","created_at":"2025-09-13T06:01:26.3283321Z","response":"","done":true,"done_reason":"stop","context":[128006,9125,128007,271,38766,1303,33025,2696,25,6790,220,2366,18,271,128009,128006,882,128007,271,10445,374,279,13180,6437,30,128009,128006,78191,128007,271,791,13180,8111,6437,1606,315,264,25885,2663,13558,64069,72916,11,7086,1306,279,8013,83323,10425,13558,64069,13,3277,40120,29933,9420,596,16975,11,433,35006,13987,35715,315,45612,1778,439,47503,323,24463,382,9673,35715,45577,279,3177,304,682,18445,11,719,814,45577,24210,320,12481,8,93959,810,1109,5129,320,1171,8,93959,13,1115,374,1606,279,9333,35715,527,810,7524,520,72916,279,24210,93959,382,2170,264,1121,11,279,6437,3177,374,77810,6957,279,16975,11,19261,1057,6548,505,682,5596,315,279,13180,13,1115,374,3249,279,13180,11383,8111,6437,2391,279,62182,11,5423,304,279,5216,315,279,7160,382,8586,596,264,44899,16540,1473,16,13,8219,4238,29933,9420,596,16975,627,17,13,578,13987,35715,304,279,3805,45577,279,24210,320,12481,8,93959,810,1109,279,5129,320,1171,8,93959,627,18,13,578,38067,6437,3177,25501,1057,6548,505,682,5596,315,279,13180,627,19,13,5751,6548,45493,420,38067,6437,3177,439,279,1933,6437,382,2181,596,5922,27401,430,279,1933,315,279,13180,649,13592,11911,389,3892,9547,11,1778,439,1473,9,4212,315,1938,25,12220,64919,323,44084,11,279,13180,649,1935,389,82757,315,2579,11,19087,11,323,18718,4245,311,279,72916,315,5129,93959,627,9,87597,4787,25,33093,11,25793,11,323,3090,38752,304,279,3805,649,45577,3177,323,2349,1202,11341,627,9,24610,3993,323,45475,7410,25,578,1933,315,279,13180,649,1101,387,11754,555,4442,304,36958,323,45475,7410,382,11458,11,1234,2867,4787,2391,279,62182,11,13558,64069,72916,374,279,6156,2944,3249,279,13180,8111,6437,13],"total_duration":14593162500,"load_duration":1624516000,"prompt_eval_count":31,"prompt_eval_duration":338638600,"eval_count":313,"eval_duration":12628832700}

# %%
# 方法2：處理流式回應（如果 Ollama 支援）
import requests
import json

url = "http://localhost:11434/api/generate"

# 準備請求資料，包含流式回應設定
data = {
    "model": "llama3.2",
    "prompt": "Why is the sky blue?",
    "stream": False  # 設為 False 表示要完整回應，True 表示流式回應
}

try:
    # 發送 POST 請求
    response = requests.post(url, json=data, timeout=30)
    
    # 檢查回應狀態
    if response.status_code == 200:
        # 解析 JSON 回應
        result = response.json()
        print("模型回應:")
        print(result.get('response', '無回應內容'))
    else:
        print(f"請求失敗，狀態碼: {response.status_code}")
        print(f"錯誤訊息: {response.text}")
        
except requests.exceptions.RequestException as e:
    print(f"請求發生錯誤: {e}")
except json.JSONDecodeError as e:
    print(f"JSON 解析錯誤: {e}")
    print(f"原始回應: {response.text}")
# Out:
# 模型回應:
# The sky appears blue because of a phenomenon called Rayleigh scattering, named after the British physicist Lord Rayleigh, who first described it in the late 19th century.
#
# Here's what happens:
#
# 1. **Sunlight enters Earth's atmosphere**: When sunlight enters our atmosphere, it encounters tiny molecules of gases such as nitrogen (N2) and oxygen (O2).
# 2. **Scattering occurs**: These gas molecules scatter the light in all directions, but they scatter shorter (blue) wavelengths more than longer (red) wavelengths.
# 3. **Blue light is scattered**: The blue light is scattered in all directions by the tiny gas molecules, which is why it reaches our eyes from all parts of the sky.
# 4. **Red light continues straight**: On the other hand, the longer wavelengths of light, such as red and orange, continue to travel in a more direct path through the atmosphere without being scattered much.
#
# As a result, when we look up at the sky, we see mostly the blue light that has been scattered by the gas molecules, while the red light continues straight ahead and reaches our eyes only from a relatively small area near the horizon. This is why the sky appears blue, especially during the daytime when the sun is overhead.
#
# **Other factors can affect the color of the sky:**
#
# * **Time of day**: During sunrise and sunset, the sun's rays pass through more of the Earth's atmosphere, which scatters the shorter wavelengths of light even more. This is why the sky often appears red or orange during these times.
# * **Atmospheric conditions**: Dust, pollution, and water vapor in the air can also scatter light and change the color of the sky.
# * **Altitude**: The higher you go, the thinner the atmosphere becomes, and the more intense the blue color of the sky appears.
#
# So, there you have it! The sky's blue color is a beautiful result of the physics of light scattering in our atmosphere.

# %%
# 方法3：流式回應處理（即時顯示回應內容）
import requests
import json

url = "http://localhost:11434/api/generate"

# 準備請求資料，啟用流式回應
data = {
    "model": "llama3.2",
    "prompt": "Why is the sky blue?",
    "stream": True  # 啟用流式回應
}

try:
    # 發送 POST 請求，啟用流式回應
    response = requests.post(url, json=data, stream=True, timeout=30)
    
    if response.status_code == 200:
        print("模型回應（流式）:")
        print("-" * 50)
        
        # 逐行讀取流式回應
        for line in response.iter_lines():
            if line:
                try:
                    # 解析每一行的 JSON 資料
                    json_data = json.loads(line.decode('utf-8'))
                    
                    # 檢查是否有回應內容
                    if 'response' in json_data:
                        print(json_data['response'], end='', flush=True)
                    
                    # 檢查是否完成
                    if json_data.get('done', False):
                        print("\n" + "-" * 50)
                        print("回應完成！")
                        break
                        
                except json.JSONDecodeError:
                    # 如果無法解析 JSON，直接顯示原始內容
                    print(line.decode('utf-8'), end='')
    else:
        print(f"請求失敗，狀態碼: {response.status_code}")
        print(f"錯誤訊息: {response.text}")
        
except requests.exceptions.RequestException as e:
    print(f"請求發生錯誤: {e}")
