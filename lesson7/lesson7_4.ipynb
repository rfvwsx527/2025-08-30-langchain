# %%
import os
from langchain.text_splitter import CharacterTextSplitter
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings

# 定義包含文字檔案的目錄和持久化目錄
current_dir = os.path.dirname(os.path.abspath("__file__"))
books_dir = os.path.join(current_dir, "books")
db_dir = os.path.join(current_dir, "db")
persistent_directory = os.path.join(db_dir, "chroma_db_with_metadata_chinese_nb")

print(f"書籍目錄: {books_dir}")
print(f"持久化目錄: {persistent_directory}")

# 檢查 Chroma 向量存儲是否已存在
if not os.path.exists(persistent_directory):
    print("持久化目錄不存在。正在初始化向量存儲...")

    # 確保書籍目錄存在
    if not os.path.exists(books_dir):
        raise FileNotFoundError(
            f"目錄 {books_dir} 不存在。請檢查路徑。"
        )

    # 列出目錄中所有文字檔案
    book_files = [f for f in os.listdir(books_dir) if f.endswith(".txt")]

    # 從每個檔案讀取文字內容並儲存元數據
    documents = []
    for book_file in book_files:
        file_path = os.path.join(books_dir, book_file)
        loader = TextLoader(file_path)
        book_docs = loader.load()
        for doc in book_docs:
            # 為每個文件添加元數據以指示其來源
            doc.metadata = {"source": book_file}
            documents.append(doc)

    # 將文件分割成塊
    text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
    docs = text_splitter.split_documents(documents)

    # 顯示分割文件的資訊
    print("\n--- 文件塊資訊 ---")
    print(f"文件塊數量: {len(docs)}")

    # 建立嵌入模型
    print("\n--- 正在建立嵌入 ---")
    embeddings = HuggingFaceEmbeddings(
        model_name="BAAI/bge-m3"
    )
    print("\n--- 完成建立嵌入 ---")

    # 建立並持久化向量存儲
    print("\n--- 正在建立並持久化向量存儲 ---")
    db = Chroma.from_documents(
        docs, embeddings, persist_directory=persistent_directory)
    print("\n--- 完成建立並持久化向量存儲 ---")

else:
    print("向量存儲已存在。無需初始化。")
# Out:
# 書籍目錄: /Users/roberthsu2003/Documents/GitHub/__2025_08_30__chihlee_langchain__/lesson7/books
# 持久化目錄: /Users/roberthsu2003/Documents/GitHub/__2025_08_30__chihlee_langchain__/lesson7/db/chroma_db_with_metadata_chinese_nb
# 持久化目錄不存在。正在初始化向量存儲...
#
# --- 文件塊資訊 ---
# 文件塊數量: 81
#
# --- 正在建立嵌入 ---
# /var/folders/7g/kb_wcfhj3710_xnyqdgx_v940000gn/T/ipykernel_13754/2351684797.py:50: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# --- 完成建立嵌入 ---
#
# --- 正在建立並持久化向量存儲 ---
#
# --- 完成建立並持久化向量存儲 ---

# %%
import os
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings

# 定義持久化目錄
current_dir = os.path.dirname(os.path.abspath("__file__"))
db_dir = os.path.join(current_dir, "db")
persistent_directory = os.path.join(db_dir, "chroma_db_with_metadata_chinese_nb")

# 定義嵌入模型
embeddings = HuggingFaceEmbeddings(model_name="BAAI/bge-m3")

# 使用嵌入函數載入現有的向量存儲
db = Chroma(persist_directory=persistent_directory,
            embedding_function=embeddings)

# 定義使用者的問題
query = "什麼是紅利點數卡"

# 根據查詢檢索相關文件
# search_type="similarity_score_threshold": 使用相似度分數閾值過濾
# k=3: 返回最多 3 個相關文件
# score_threshold=0.1: 較低的閾值，可以返回更多相關文件
retriever = db.as_retriever(
    search_type="similarity_score_threshold",
    search_kwargs={"k": 3, "score_threshold": 0.3},
)
relevant_docs = retriever.invoke(query)

# 顯示相關結果及元數據
print("\n--- 相關文件 ---")
for i, doc in enumerate(relevant_docs, 1):
    print(f"文件 {i}:\n{doc.page_content}\n")
    print(f"來源: {doc.metadata['source']}\n")

# # 進階查詢：只從特定來源檢索
# print("\n--- 只從《路由器設定手冊》檢索 ---")
# # 使用 filter 參數指定元數據條件
# specific_docs = db.similarity_search(
#     query,
#     k=3,
#     filter={"source": "路由器設定手冊.txt"}
# )

# for i, doc in enumerate(specific_docs, 1):
#     print(f"文件 {i}:\n{doc.page_content}\n")
#     print(f"來源: {doc.metadata['source']}\n")
# Out:
# --- 相關文件 ---
# 文件 1:
# 密碼安全建議：
# - 勿使用生日、電話等
# - 定期更換密碼
# - 不同服務使用不同密碼
# - 妥善保管密碼
#
# ========================================
# 第二章：紅利點數累積與兌換
# ========================================
#
# 2.1 點數累積規則
# ----------------------------------------
# 基本累積（紅利點數卡）：
# - 一般消費：每 20元 = 1點
# - 指定通路：每 10元 = 1點
# - 海外消費：每 15元 = 1點
#
# 指定通路加碼（每月更新）：
# - 便利商店：10元 = 1點
# - 量販超市：10元 = 1點
# - 加油站：10元 = 1點
# - 百貨公司：10元 = 1點
# - 線上購物：10元 = 1點
#
# 特殊加碼活動：
# - 生日當月：點數 2倍送
# - 新卡首刷：贈送 3,000點
# - 推薦辦卡：每成功推薦贈 1,000點
# - 滿額加碼：單筆滿萬元加贈 500點
#
# 點數計算範例：
# 消費 1,000元於一般商店：
# 1,000 ÷ 20 = 50點
#
# 消費 1,000元於超市（指定通路）：
# 1,000 ÷ 10 = 100點
#
# 消費 1,000元於生日當月超市：
# (1,000 ÷ 10) × 2 = 200點
#
# 不累積點數項目：
# - 預借現金
# - 繳納稅款、規費
# - 繳納電信費、保費（部分銀行）
# - 分期付款手續費
# - 循環利息
# - 年費
#
# 2.2 點數查詢
# ----------------------------------------
# 查詢管道：
#
# 電話查詢：
# 1. 撥打客服專線 02-8888-9999
# 2. 選擇「點數查詢」
# 3. 輸入身分證字號與電話密碼
# 4. 語音播報點數餘額
#
# 網路查詢：
# 1. 登入網路銀行
# 2. 點選「信用卡」→「紅利點數」
# 3. 查看累積點數、即將到期點數
#
# App查詢：
# 1. 開啟 TW Bank App
# 2. 首頁顯示點數摘要
# 3. 點入可查看詳細累兌記錄
#
# 電子帳單：
# - 每月帳單載明當期累積點數
# - 顯示點數餘額
# - 提醒即將到期點數
#
# 簡訊通知：
# - 可設定點數異動通知
# - 到期前 30天提醒
# - 累積達門檻提醒
#
# 來源: 信用卡權益說明.txt
#
# 文件 2:
# 電子帳單：
# - 每月帳單載明當期累積點數
# - 顯示點數餘額
# - 提醒即將到期點數
#
# 簡訊通知：
# - 可設定點數異動通知
# - 到期前 30天提醒
# - 累積達門檻提醒
#
# 2.3 點數兌換
# ----------------------------------------
# 兌換管道：
#
# 線上兌換（24小時）：
# 1. 登入紅利點數網站
# 2. 瀏覽兌換商品目錄
# 3. 加入購物車
# 4. 確認兌換
# 5. 填寫收件資訊
# 6. 3-5個工作天配送
#
# 電話兌換：
# 1. 撥打客服專線
# 2. 選擇「點數兌換」
# 3. 告知商品編號
# 4. 確認兌換與收件地址
#
# App兌換：
# 1. 開啟 App
# 2. 點選「點數兌換」
# 3. 選擇商品
# 4. 一鍵兌換
#
# 熱門兌換商品：
#
# 家電類（價值範例）：
# - 吸塵器：8,000點
# - 氣炸鍋：12,000點
# - 電子鍋：15,000點
# - 咖啡機：20,000點
# - 電視：50,000點
#
# 3C類：
# - 藍牙耳機：6,000點
# - 行動電源：3,000點
# - 無線滑鼠：2,000點
# - 智慧手環：10,000點
#
# 生活用品：
# - 保溫瓶：1,500點
# - 行李箱：8,000點
# - 床組：12,000點
# - 鍋具組：5,000點
#
# 超商兌換券：
# - 100元商品券：500點
# - 200元商品券：1,000點
# - 500元商品券：2,500點
#
# 航空哩程：
# - 長榮航空：3點 = 1哩
# - 華航：3點 = 1哩
# - 星宇航空：2.5點 = 1哩
#
# 現金折抵：
# - 100點 = 5元帳單折抵
# - 最低 500點起兌
# - 直接抵扣帳單金額
#
# 2.4 點數管理
# ----------------------------------------
# 點數有效期限：
# - 本行紅利點數：永久有效
# - 合作夥伴點數：依各夥伴規定
# - 兌換後商品：依商品保固規定
#
# 點數轉讓：
# - 可轉讓予同戶附卡持卡人
# - 轉讓最低 1,000點
# - 每次收取 100點手續費
# - 需本人電話確認
#
# 點數繼承：
# - 持卡人身故，點數可由繼承人繼承
# - 需提供死亡證明與繼承證明
# - 繼承人須為本行持卡人
#
# 點數保護：
# - 卡片遺失補發，點數保留
# - 盜刷消費的點數會扣回
# - 退貨消費的點數會扣回
#
# 點數使用策略：
# 建議 1：集中消費
# - 主力使用一張卡累積點數
# - 避免點數分散
#
# 來源: 信用卡權益說明.txt
#
# 文件 3:
# 信用卡權益說明
# ========================================
#
# 發卡銀行：台灣聯合銀行
# 卡片名稱：尊榮現金回饋信用卡
# 客服專線：02-8888-9999（24小時）
# 官方網站：www.twbank.com.tw
#
# ========================================
# 第一章：卡片類型與申請
# ========================================
#
# 1.1 卡片類型介紹
# ----------------------------------------
# 尊榮現金回饋卡（主推）
# - 年費：正卡 3,000元，附卡 1,500元
# - 首年免年費，次年刷滿 12萬免年費
# - 國內消費 1.2% 現金回饋
# - 海外消費 2.5% 現金回饋
# - 機場接送服務 4次/年
# - 機場貴賓室免費使用
#
# 紅利點數卡
# - 年費：正卡 2,000元，附卡 1,000元
# - 首年免年費，次年刷滿 8萬免年費
# - 國內消費 20元 = 1點
# - 指定通路 10元 = 1點
# - 點數永久有效
# - 可兌換商品、哩程
#
# 學生卡（18-25歲）
# - 終身免年費
# - 國內消費 0.5% 回饋
# - 海外消費 1.5% 回饋
# - 額度上限 5萬元
# - 須檢附學生證
#
# 樂活卡（55歲以上）
# - 首年免年費
# - 藥局、醫院 3% 回饋
# - 超市、量販 2% 回饋
# - 其他 0.8% 回饋
# - 免費健檢乙次/年
#
# 商務卡（企業戶）
# - 年費 5,000元
# - 額度依營業額核定
# - 專屬企業祕書服務
# - 差旅預訂優惠
# - 費用管理報表
#
# 1.2 申請資格
# ----------------------------------------
# 基本條件：
# □ 年滿 20歲（學生卡 18歲）
# □ 有固定收入
# □ 信用紀錄良好
# □ 檢附財力證明
#
# 所需文件：
#
# 身分證明：
# - 身分證正反面影本
# - 外籍人士：護照 + 居留證
#
# 財力證明（擇一）：
# - 薪資轉帳證明（近 3個月）
# - 扣繳憑單
# - 所得清單
# - 不動產證明
# - 定存證明
#
# 在職證明：
# - 公司識別證
# - 在職證明書
# - 勞保異動明細
#
# 來源: 信用卡權益說明.txt

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_ollama import ChatOllama

# 定義使用者的問題
question = "如何保養洗衣機和路由器？"

print(f"❓ 使用者問題: {question}\n")

# 步驟 1: 從多個來源檢索相關文件
print("=" * 70)
print("步驟 1: 從多個來源檢索相關文件")
print("=" * 70)

retriever = db.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 4}  # 取4個相關文件（可能來自不同手冊）
)

retrieved_docs = retriever.invoke(question)

print(f"✅ 找到 {len(retrieved_docs)} 個相關文件\n")
for i, doc in enumerate(retrieved_docs, 1):
    source = doc.metadata.get('source', 'Unknown')
    print(f"📄 文件 {i} - 來源: {source}")
    print(f"   內容: {doc.page_content[:80]}...\n")

# 步驟 2: 建立帶有來源標註的 RAG Chain
print("=" * 70)
print("步驟 2: 建立多來源 RAG Chain")
print("=" * 70)

# 定義提示模板（強調來源資訊）
template = """你是一個專業的產品客服助手。請根據以下多個產品手冊的參考資料回答使用者的問題。

參考資料：
{context}

使用者問題：{question}

回答要求：
1. 針對不同產品分別說明（如果問題涉及多個產品）
2. 在回答中標註資訊來源（例如：「根據洗衣機使用說明...」）
3. 只根據參考資料回答，不要編造內容
4. 如果某個產品的資訊不足，請說明
5. 用條列式整理，讓使用者容易閱讀

回答："""

prompt = ChatPromptTemplate.from_template(template)

# 建立 LLM
llm = ChatOllama(model="gpt-oss:20b", temperature=0)

# 定義文件格式化函數（包含來源資訊）
def format_docs_with_source(docs):
    formatted = []
    for i, doc in enumerate(docs, 1):
        source = doc.metadata.get('source', 'Unknown')
        formatted.append(f"【來源 {i}: {source}】\n{doc.page_content}")
    return "\n\n---\n\n".join(formatted)

# 建立完整的 RAG Chain（整合 3_chains 的技巧）
rag_chain = (
    {
        "context": retriever | format_docs_with_source, 
        "question": RunnablePassthrough()
    }
    | prompt
    | llm
    | StrOutputParser()
)

print("✅ 多來源 RAG Chain 建立完成\n")

# 步驟 3: 執行 Chain 並取得整合答案
print("=" * 70)
print("步驟 3: 執行 Chain 取得整合答案")
print("=" * 70)

answer = rag_chain.invoke(question)

print(f"\n🤖 【AI 整合回答】\n")
print(answer)
print()

# 步驟 4: 示範使用元數據過濾的 Chain
print("=" * 70)
print("步驟 4: 只查詢特定來源的 Chain")
print("=" * 70)

specific_question = "路由器如何設定？"
print(f"❓ 問題: {specific_question}\n")

# 創建只查詢路由器手冊的檢索器
def retrieve_from_router_manual(query):
    docs = db.similarity_search(
        query,
        k=3,
        filter={"source": "路由器設定手冊.txt"}
    )
    return docs

# 建立特定來源的 Chain
specific_chain = (
    {
        "context": RunnablePassthrough() | retrieve_from_router_manual | format_docs_with_source,
        "question": RunnablePassthrough()
    }
    | prompt
    | llm
    | StrOutputParser()
)

specific_answer = specific_chain.invoke(specific_question)
print(f"🤖 【只查路由器手冊的回答】\n")
print(specific_answer)
print()

print("=" * 70)
print("📚 多來源 RAG Chain 的優勢")
print("=" * 70)
print("✅ 可以同時查詢多個產品手冊")
print("✅ 自動標註資訊來源，方便追蹤")
print("✅ 可以用 metadata 過濾特定來源")
print("✅ 整合多個文件的資訊給出完整答案")
print("\n💡 這展示了 Chain 3 中學到的組合技巧在 RAG 中的應用！")
# Out:
# ❓ 使用者問題: 如何保養洗衣機和路由器？
#
# ======================================================================
# 步驟 1: 從多個來源檢索相關文件
# ======================================================================
# ✅ 找到 4 個相關文件
#
# 📄 文件 1 - 來源: 洗衣機使用說明.txt
#    內容: 5.2 每週保養
# 清潔洗劑盒:
# 1. 將洗劑盒完全拉出(按住中央釋放鈕)
# 2. 用溫水沖洗各個槽
# 3. 用舊牙刷清潔細部
# 4. 擦乾後裝回
#
# 清潔門圈橡膠:
# 1...
#
# 📄 文件 2 - 來源: 洗衣機使用說明.txt
#    內容: 7.3 維護安全
# - 清潔前務必拔掉電源插頭
# - 請勿用水直接沖洗洗衣機
# - 請勿使用強酸強鹼清潔劑
# - 維修時請聯絡專業人員
#
# 7.4 緊急處理
# 發生以下情況...
#
# 📄 文件 3 - 來源: 路由器設定手冊.txt
#    內容: 步驟 5：重置路由器
# 最後手段（將恢復原廠設定）：
# 1. 找到路由器背面 Reset孔
# 2. 使用迴紋針按住 10秒
# 3. 指示燈全亮後放開
# 4. 等待重新啟動...
#
# 📄 文件 4 - 來源: 洗衣機使用說明.txt
#    內容: 問題:漏水
# 可能原因與解決方法:
# 1. 檢查進水管接頭是否鎖緊
# 2. 檢查排水管是否正確安裝
# 3. 檢查洗劑盒是否正確關閉
# 4. 檢查使用的洗劑是否過量(泡沫溢...
#
# ======================================================================
# 步驟 2: 建立多來源 RAG Chain
# ======================================================================
# ✅ 多來源 RAG Chain 建立完成
#
# ======================================================================
# 步驟 3: 執行 Chain 取得整合答案
# ======================================================================
#
# 🤖 【AI 整合回答】
#
# **洗衣機保養（根據《洗衣機使用說明》）**
#
# | 頻率 | 主要項目 | 具體步驟 | 參考來源 |
# |------|----------|----------|----------|
# | **每週** | 洗劑盒清潔 | 1. 拉出洗劑盒（按住中央釋放鈕）<br>2. 用溫水沖洗各槽<br>3. 用舊牙刷清潔細部<br>4. 擦乾後裝回 | 【來源 1】 |
# | | 門圈橡膠清潔 | 1. 拉開橡膠圈<br>2. 用濕布擦拭內側摺疊處<br>3. 檢查硬幣、髮夾等異物<br>4. 用乾布擦乾 | 【來源 1】 |
# | **每月** | 排水濾網清潔 | 1. 關閉電源並拔掉插頭<br>2. 打開右下角維修蓋板<br>3. 準備淺盤接水<br>4. 逆時針旋轉濾網蓋取出<br>5. 清除棉絮、異物<br>6. 用清水沖洗<br>7. 檢查底座、清除積水<br>8. 裝回並鎖緊 | 【來源 1】 |
# | | 滾筒清潔 | 1. 清空洗衣機<br>2. 選擇「滾筒清潔」程式（或 90 °C 棉質洗衣程式）<br>3. 加入專用清潔劑或 200 ml 白醋<br>4. 啟動程式運轉<br>5. 完成後保持門開啟通風 | 【來源 1】 |
# | | 防臭/防霉 | 1. 使用後保持門開啟<br>2. 定期清潔門圈橡膠<br>3. 每月執行滾筒清潔程式<br>4. 使用低泡沫洗劑<br>5. 避免過量使用洗劑與柔軟精<br>6. 保持周圍通風乾燥 | 【來源 1】 |
# | | 有異味時的處理 | 1. 用 200 ml 白醋 + 50 g 小蘇打粉倒入洗劑盒<br>2. 執行 90 °C 空轉程式<br>3. 完成後用清水再執行一次漂洗程式<br>4. 擦乾滾筒內部<br>5. 保持門開啟通風 24 h | 【來源 1】 |
#
# > **安全提醒**
# > - 清潔前務必拔掉電源插頭（【來源 2】）。
# > - 請勿用水直接沖洗洗衣機，亦勿使用強酸強鹼清潔劑（【來源 4】）。
# > - 如發現異常噪音、煙霧或漏電，請立即關閉電源並聯絡客服（【來源 2】）。
#
# ---
#
# **路由器保養（根據《路由器設定手冊》）**
#
# | 項目 | 具體步驟 | 參考來源 |
# |------|----------|----------|
# | **韌體更新** | 1. 登入管理介面 →「系統設定」→「韌體更新」<br>2. 點選「檢查更新」<br>3. 若有新版本，點選「下載」並安裝<br>4. 建議啟用「自動檢查更新」並設定凌晨 3‑4 點下載<br>5. 更新前備份設定（備份檔案 .cfg）<br>6. 使用有線連接，避免中斷電源 | 【來源 3】 |
# | | 手動更新 | 1. 於官網下載 .bin 檔案<br>2. 管理介面 →「韌體更新」→「手動更新」<br>3. 選擇檔案並上傳<br>4. 等待約 5 分鐘完成（勿中斷電源） | 【來源 3】 |
# | **備份與還原設定** | 1. 「系統設定」→「備份/還原」→「備份目前設定」<br>2. 下載 .cfg 檔案並妥善保存<br>3. 需要還原時，選擇「選擇檔案」上傳 .cfg，點選「還原」 | 【來源 3】 |
# | | 建議備份時機 | - 完成初次設定後<br>- 更改重要設定前<br>- 韌體更新前<br>- 每月一次 | 【來源 3】 |
# | **恢復原廠設定** | 方式一：管理介面 →「系統設定」→「恢復原廠」→「確定」<br>方式二：按住 Reset 鍵 10 秒，所有設定將清除 | 【來源 3】 |
# | **遠端管理設定** | 透過手機 App 或網頁設定遠端管理功能，方便外出時監控連線狀態與流量 | 【來源 3】 |
#
# > **備註**
# > - 若路由器出現異常（如無法連線、頻繁重啟等），可先嘗試重置或更新韌體。
# > - 若資訊不足（例如特定型號的進階設定），請參考官方網站或聯絡客服。
#
# ---
#
# **總結**
# - **洗衣機**：每週清潔洗劑盒與門圈橡膠；每月清潔排水濾網與滾筒；定期防臭處理。
# - **路由器**：定期更新韌體、備份設定、必要時恢復原廠設定，並保持遠端管理功能正常。
#
# 如需進一步協助，歡迎聯絡客服或參考官方網站。
#
# ======================================================================
# 步驟 4: 只查詢特定來源的 Chain
# ======================================================================
# ❓ 問題: 路由器如何設定？
#
# 🤖 【只查路由器手冊的回答】
#
# **路由器設定流程（以 TR‑5000 系列為例）**
# （以下步驟結合三份手冊中的資訊，若您使用其他型號，請參照相同邏輯調整）
#
# ---
#
# ### 1️⃣ 先備工作：接電源 & 開啟數據機
# | 步驟 | 操作 | 參考來源 |
# |------|------|----------|
# | 1 | **接電源**：將電源變壓器接至路由器 → 插上插座 → 按下背面電源開關 → 等待 60‑90 秒啟動完成 | 【來源 2】 |
# | 2 | **開啟數據機**：開啟數據機電源 → 等待約 2 分鐘 → 確認指示燈正常 | 【來源 2】 |
# | 3 | **確認啟動**：電源燈綠、Internet 燈亮、Wi‑Fi 燈綠、可搜尋預設 Wi‑Fi | 【來源 2】 |
#
# ---
#
# ### 2️⃣ 連接路由器（有線或無線）
# | 方式 | 操作 | 參考來源 |
# |------|------|----------|
# | A | **有線連接**：使用網路線將電腦連到路由器 LAN 埠 | 【來源 2】 |
# | B | **無線連接**：搜尋預設 Wi‑Fi 名稱（如 `TR‑5000_XXXX`） → 輸入預設密碼（8 位數字） | 【來源 2】 |
#
# ---
#
# ### 3️⃣ 進入管理介面
# | 步驟 | 操作 | 參考來源 |
# |------|------|----------|
# | 1 | 開啟瀏覽器（Chrome/Edge/Safari） | 【來源 2】 |
# | 2 | 輸入網址 `http://192.168.1.1` 或 `http://router.setup` | 【來源 2】 |
# | 3 | 預設帳號/密碼：`admin / admin` → 首次登入會要求更改密碼 | 【來源 2】 |
#
# ---
#
# ### 4️⃣ 快速設定精靈（首次設定）
# | 步驟 | 操作 | 參考來源 |
# |------|------|----------|
# | 1 | **設定管理員密碼**：建議 8‑16 位英數混合，包含大小寫字母與數字 | 【來源 2】 |
# | 2 | **選擇時區**：如「台北（GMT+8）」 | 【來源 2】 |
# | 3 | **網際網路連線設定**：根據 ISP 選擇<br>• PPPOE：輸入帳號、密碼、測試連線<br>• 動態 IP：選「自動取得 IP」<br>• 固定 IP：輸入 IP、子網路遮罩、閘道、DNS | 【來源 2】 |
# | 4 | **完成設定**：點選「完成」 → 路由器重啟約 30 秒 → 重新連線即可上網 | 【來源 2】 |
#
# ---
#
# ### 5️⃣ Wi‑Fi 無線網路設定（可在「無線網路」→「基本設定」中調整）
# | 項目 | 建議設定 | 參考來源 |
# |------|----------|----------|
# | **SSID（網路名稱）** | 2.4 GHz：`Home_2.4G` 或 `MyHome_24`<br>5 GHz：`Home_5G` 或 `MyHome_5G` | 【來源 1】 |
# | **加密方式** | 先選「WPA3‑Personal」<br>若舊裝置不支援，選「WPA2/WPA3 混合模式」 | 【來源 1】 |
# | **密碼長度** | 8‑63 字元，建議英文大小寫+數字+符號 | 【來源 1】 |
# | **頻道設定** | 建議「自動」或手動選 1、6、11（較少干擾） | 【來源 1】 |
# | **頻道寬度** | 20/40 MHz 自動 | 【來源 1】 |
#
# ---
#
# ### 6️⃣ 進階設定（如韌體更新、備份還原、遠端管理）
# | 功能 | 操作 | 參考來源 |
# |------|------|----------|
# | **韌體更新** | `系統設定` → `韌體更新` → `檢查更新` / `手動更新`（上傳 .bin 檔） | 【來源 3】 |
# | **備份設定** | `系統設定` → `備份/還原` → `備份目前設定` → 下載 .cfg 檔 | 【來源 3】 |
# | **還原設定** | `系統設定` → `備份/還原` → 上傳 .cfg 檔 → `還原` | 【來源 3】 |
# | **遠端管理** | 透過手機 App 或網頁設定遠端管理功能 | 【來源 3】 |
#
# ---
#
# ### 7️⃣ 如需恢復原廠設定
# | 方法 | 操作 | 參考來源 |
# |------|------|----------|
# | 1 | 管理介面：`系統設定` → `恢復原廠` → 確定 | 【來源 3】 |
# | 2 | Reset 鍵：按住 10 秒 → 指示燈全亮 → 放開 → 重新啟動 | 【來源 3】 |
#
# ---
#
# > **備註**
# > - 若您使用的路由器型號與 TR‑5000 不同，請確認其預設 IP、帳號、密碼與手冊中的相符。
# > - 手冊中未提及的功能（如 VLAN、QoS 等）請參考官方技術文件或客服支援。
# > - 所有操作均以手冊內容為準，未做任何額外假設。
#
# ======================================================================
# 📚 多來源 RAG Chain 的優勢
# ======================================================================
# ✅ 可以同時查詢多個產品手冊
# ✅ 自動標註資訊來源，方便追蹤
# ✅ 可以用 metadata 過濾特定來源
# ✅ 整合多個文件的資訊給出完整答案
#
# 💡 這展示了 Chain 3 中學到的組合技巧在 RAG 中的應用！
